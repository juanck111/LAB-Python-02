# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-02/blob/main/ejercicio04_sorted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a. Ordenar lista de palabras alfabéticamente
orden_alfabetico = sorted(palabras, key=str.lower)

# b. Ordenar lista de tuplas por el primer elemento
tuplas = [(3, "c"), (1, "a"), (2, "b")]
tuplas_ordenadas = sorted(tuplas, key=lambda x: x[0])

# c. Lista de diccionarios (el enunciado da tuplas, asumiremos tuplas como dice tu código de ejemplo)
ropa = [
    ("Camisa", 30),
    ("Pantalón", 55),
    ("Medias", 10),
    ("Chaqueta", 80)
]
# Ordenar por precio (índice 1) mayor a menor, luego por nombre (índice 0)
ropa_ordenada = sorted(ropa, key=lambda p: (-p[1], p[0]))

# d. Ordenar palabras según su longitud
orden_por_longitud = sorted(palabras, key=len)

# e. Primero pares, luego impares (y ordenados ascendentemente dentro de su grupo)
orden_pares_impares = sorted(numeros, key=lambda x: (x % 2 != 0, x))

# f. Palabra a diccionario de apariciones, ordenado por frecuencia
palabra_prueba = "programacion"
conteo_letras = {letra: palabra_prueba.count(letra) for letra in set(palabra_prueba)}
letras_ordenadas = sorted(conteo_letras.items(), key=lambda x: x[1], reverse=True)

# g. Empleados por departamento y edad
empleados = [
    ("Maria", "Ventas", 30),
    ("Luis", "Tecnología", 25),
    ("Ana", "Ventas", 25),
    ("Pedro", "Tecnología", 28)
]
empleados_ordenados = sorted(empleados, key=lambda e: (e[1], e[2]))

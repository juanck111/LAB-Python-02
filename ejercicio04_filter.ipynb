# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-02/blob/main/ejercicio04_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a. Palabras con más de 4 letras
mas_de_4 = list(filter(lambda p: len(p) > 4, palabras))

# b. Filtrar elementos nulos
lista_mezclada = [1, None, 2, "hola", None, 3]
sin_nulos = list(filter(lambda x: x is not None, lista_mezclada))

# c. Palabras que empiezan por vocal
vocales = ('a', 'e', 'i', 'o', 'u')
empieza_vocal = list(filter(lambda p: p.lower().startswith(vocales), palabras))

# d. Filtrar palíndromos
lista_palabras = ["oso", "radar", "python", "ana", "sol"]
palindromos = list(filter(lambda p: p.lower() == p.lower()[::-1], lista_palabras))

# e. Números que terminan en 5
terminan_en_5 = list(filter(lambda n: str(n).endswith('5'), numeros))

# f. Productos con precio mayor a 100
productos = [
    {"nombre": "Teclado", "precio": 80},
    {"nombre": "Mouse", "precio": 40},
    {"nombre": "Monitor", "precio": 300},
    {"nombre": "Webcam", "precio": 150}
]
productos_caros = list(filter(lambda p: p["precio"] > 100, productos))

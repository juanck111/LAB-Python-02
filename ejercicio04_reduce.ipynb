# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-02/blob/main/ejercicio04_reduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from functools import reduce

# a. Multiplicación de una lista de números
multiplicacion = reduce(lambda x, y: x * y, [1, 2, 3, 4, 5])

# b. Concatenar palabras en una sola
frase = reduce(lambda x, y: x + " " + y, palabras) # Agregué espacio para legibilidad

# c. Hallar el mayor con función auxiliar
def obtener_mayor(a, b):
    return a if a > b else b

mayor_numero = reduce(obtener_mayor, numeros)

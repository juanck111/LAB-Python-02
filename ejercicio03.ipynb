# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-02/blob/main/ejercicio03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# a. Celsius a Fahrenheit
fahrenheit_map = list(map(lambda c: (c * 9/5) + 32, celsius))

# b. Sumar dos listas elemento a elemento
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]
suma_listas = list(map(lambda x, y: x + y, lista1, lista2))

# c. Áreas de círculos dados sus radios
radios = [1, 2, 3, 5]
areas = list(map(lambda r: math.pi * (r ** 2), radios))

# d. Diccionario a lista de tuplas (nombre, valor+10%)
precios = {"pan": 1000, "leche": 2500, "café": 5000}
precios_aumentados = list(map(lambda item: (item[0], item[1] * 1.10), precios.items()))

# e. Matriz por 10
matriz_por_10 = list(map(lambda fila: list(map(lambda x: x * 10, fila)), matriz))
